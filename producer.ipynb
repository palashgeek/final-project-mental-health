# %%
import pandas as pd

from kafka import KafkaProducer
from time import sleep
from json import dumps
import json

# %%
producer = KafkaProducer(bootstrap_servers=['43.204.111.215'],
                         value_serializer=lambda x:
                         dumps(x).encode('utf-8'))

# %%
producer.send('demo_testing5', value="{'name':'palash'}")

# %%
df = pd.read_csv("mental_health_dataset/data/mHealth_subject1.csv")

# %%
df.head()
# Out:
#    acceleration from the chest sensor (X axis)  \
# 0                                      -9.8184
# 1                                      -9.8489
# 2                                      -9.6602
# 3                                      -9.6507
# 4                                      -9.7030
#
#    acceleration from the chest sensor (Y axis)  \
# 0                                     0.009971
# 1                                     0.524040
# 2                                     0.181850
# 3                                     0.214220
# 4                                     0.303890
#
#    acceleration from the chest sensor (Z axis)  \
# 0                                      0.29563
# 1                                      0.37348
# 2                                      0.43742
# 3                                      0.24033
# 4                                      0.31156
#
#    electrocardiogram signal (lead 1)  electrocardiogram signal (lead 2)  \
# ...

# %%
while True:
    dict_health = df.sample(1).to_dict(orient="records")
    producer.send('demo_testing5', value=dict_health)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 3
#       1 while True:
#       2     dict_health = df.sample(1).to_dict(orient="records")
# ----> 3     producer.send('demo_testing5', value=dict_health)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\kafka\producer\kafka.py:611, in KafkaProducer.send(self, topic, value, key, headers, partition, timestamp_ms)
#     608 if batch_is_full or new_batch_created:
#     609     log.debug("Waking up the sender since %s is either full or"
#     610               " getting a new batch", tp)
# --> 611     self._sender.wakeup()
#     613 return future
#     614 # handling exceptions and record the errors;
#     615 # for API exceptions return them in the future,
#     616 # for other exceptions raise directly
#
# ...

# %%
producer.flush()
